# %% [markdown]
# ### Import Packages

# %%
from __future__ import absolute_import, division, print_function
import matplotlib.pyplot as plt

import numpy as np
from time import gmtime, strftime
import random

import os
import re

# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras

import aging as age

tf.test.gpu_device_name()

# Define directory with matlab files
# direc = 'D:/MLdata/18-01-09d-Exp/Extract Data/'
# direc  = 'D:/Nicholas_ML/18-01-09d-Exp/Extract Data/'
direc = 'D:/MLdata/'
# Define directory to save model and plots
savedir = 'D:/MLdata/Model/' + strftime("%Y-%m-%d %H-%M", gmtime()) + '/'

random.seed(135)
np.random.seed(135)

# %% [markdown]
# ### Import Data

# %%
# Optimized Data Extractor
crop_size = 750
split_size = crop_size // 3
clip_value = 2
image_grid_size = int(crop_size**2 / split_size**2)

file_num = 100

folders, files = age.file_names(direc = 'D:/MLdata/', 
                                num_samples = 1, 
                                num_exps = file_num)

length_index, split_images, Fn_label, \
Fs_label, T_label, block_label, exp_label \
= age.data_extractor(files, 
                     folders, 
                     direc = 'D:/MLdata/', 
                     crop_size = crop_size, 
                     split_size = split_size,
                     clip_value = clip_value,
                     subtract = True, 
                     log_image = True)
# Out:
# D:/MLdata/18-01-09d-Exp/Extract Data/ML_block1_Exp487.mat

# %% [markdown]
# ### Troubleshooting

# %%
# age.time_plotter(length_index, files, Fs_label, Fn_label, T_label, split_images, crop_size, split_size)

# %%
# # Show difference values for all split_images
# initial = 0
# diff = []

# down = [50,50]
# for i in range(len(length_index)):
#     #Give the experiment we are lookings at
#     print('-------------------', files[i], '-------------------')
#     final = initial + (length_index[i]-1)*image_grid_size
#     print('initial:', initial, 'final:', final)
    
#     fig, axs = plt.subplots(nrows=1, ncols=3, sharex=True, figsize = (24,24))
    
#     ax = axs[0]
#     ax.set_title(('Fs = ' + str(round(Fs_label[initial],2)) + 
#                   ', Fn = ' + str(round(Fn_label[initial],2)) +
#                   ', T = ' + str(round(T_label[initial],2))))
#     ax.axis('off')
#     ax.matshow(age.rebin(split_images[initial],down), cmap=plt.cm.gray)

#     ax = axs[1]
#     ax.set_title(('Fs = ' + str(round(Fs_label[final],2)) + 
#                   ', Fn = ' + str(round(Fn_label[final],2)) +
#                   ', T = ' + str(round(T_label[final],2))))
#     ax.axis('off')
#     ax.matshow(age.rebin(split_images[final],down), cmap=plt.cm.gray)
    
#     ax = axs[2]
#     temp = (age.rebin(split_images[final] - split_images[initial,:,:],down))
#     diff.append(temp)
#     ax.set_title(('Difference, $\Delta = $' + str(round(np.sum(temp),2))))
#     ax.axis('off')
#     ax.matshow(temp, cmap=plt.cm.gray)
    
#     plt.tight_layout()
#     plt.show()
#     initial = final + 1
# diff = np.array(diff)

# %% [markdown]
# ### Assemble Data (FORMAT MULTI-BLOCK)

# %%
# # Assemble targets, shuffle data, and assign training and testing sets
# # Note that I use the log_time values currently.
# # This makes time appear linearly spaced.  Perhaps helps CNN converge faster
# # targets = np.vstack((log_T_label,Fn_label,Fs_label)).T
# targets = np.vstack((np.log(T_label), Fs_label)).T

# test_block_ind = np.min(np.where(block_label == 4))

# train_data = split_images[:test_block_ind].clip(0)
# train_labels = targets[:test_block_ind]
# print('Training Data and Labels Completed...', train_data.shape, train_labels.shape)

# test_data = split_images[test_block_ind:].clip(0)
# test_labels = targets[test_block_ind:]
# print('Testing Data and Labels Completed...', test_data.shape, test_labels.shape)

# # TROUBLESHOOTING: Plot an array of some of the images, to try visually confirm proper selection.
# # fig,ax = plt.subplots(4,8,figsize=(20,10))
# # for i in range(32):
# #     ax[i//8,i%8].matshow(test_data[i],cmap=plt.cm.gray)
# #     ax[i//8,i%8].set_xticks(())
# #     ax[i//8,i%8].set_yticks(())

# %% [markdown]
# ### Assemble Data (RANDOM FORMAT 1-BLOCK)

# %%
train_data, train_labels, test_data, test_labels = age.assemble_1_block(split_images = split_images, 
                 T_label = T_label, 
                 Fs_label = Fs_label, 
                 Fn_label = Fs_label, 
                 block_label = block_label, 
                 image_grid_size = image_grid_size, 
                 num_out = 1, 
                 log_time = True)

# train_data, train_labels, test_data, test_labels = \
# younger(train_data, train_index, test_data, test_index, time_cut = 4)

# split_images = []
# T_label = []
# Fs_label = []
# Fn_label = []
# block_label = []

min_val = np.min([np.min(train_data), np.min(test_data)])

#Final Renormilization
train_data = (train_data - min_val)/(1 - min_val)
test_data = (test_data - min_val)/(1 - min_val)
# Out:
# Test Index Completed...
# Training Data and Labels Completed...
# Testing Data and Labels Completed...

# %% [markdown]
# ### Build CNN

# %%
#Pad data for use in inception
sess = tf.InteractiveSession()

train_data = np.tile(train_data.reshape(train_data.shape[0], train_data.shape[1],  train_data.shape[2], 1),3)

test_data = np.tile(test_data.reshape(test_data.shape[0], test_data.shape[1], test_data.shape[2], 1),3)

# train_data = tf.keras.backend.resize_images(
#     train_data,
#     10,
#     10,
#     data_format = 'channels_last',
#     interpolation='nearest'
# ).eval()

# test_data = tf.keras.backend.resize_images(
#     test_data,
#     10,
#     10,
#     data_format = 'channels_last',
#     interpolation='nearest'
# ).eval()

sess.close()

image_size = train_data.shape[1]

# %%
IMG_SHAPE = (image_size, image_size, 3)

# Create the base model
# https://keras.io/applications/#inceptionv3
base_model = tf.keras.applications.inception_v3.InceptionV3(
    include_top=False, 
    weights='imagenet', 
    input_shape=IMG_SHAPE)

base_model.trainable = False
    
model = tf.keras.Sequential([
    base_model,
    #     tf.keras.layers.AveragePooling2D(pool_size=(5, 5)),
#     tf.keras.layers.Conv2D(4, kernel_size=(2, 2), strides=(1, 1),
#                      input_shape=(test_data.shape[1],test_data.shape[2],1)),
#     tf.keras.layers.LeakyReLU(alpha=0.5),
#     tf.keras.layers.Dropout(0.4),
    #     tf.keras.layers.AveragePooling2D(pool_size=(2, 2), strides=(2, 2)),
    tf.keras.layers.Conv2D(32, (3, 3)),
    tf.keras.layers.LeakyReLU(alpha=0.5),
    tf.keras.layers.Dropout(0.4),
    #     tf.keras.layers.AveragePooling2D(pool_size=(2, 2), strides=(2, 2)),
#     tf.keras.layers.Conv2D(16, (5, 5)),
#     tf.keras.layers.LeakyReLU(alpha=0.5),
#     tf.keras.layers.Dropout(0.4),
    #     tf.keras.layers.AveragePooling2D(pool_size=(2, 2), strides=(2, 2)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(64),
    tf.keras.layers.LeakyReLU(alpha=0.5),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(1)
])

optimizer = tf.keras.optimizers.RMSprop(0.0001)

model.compile(loss='mean_squared_logarithmic_error',
            optimizer=optimizer,
            metrics=['mean_absolute_error', 'accuracy'])
# Out:
# WARNING:tensorflow:From C:\Users\Nicholas\Anaconda3\envs\Aion\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\Nicholas\Anaconda3\envs\Aion\lib\site-packages\tensorflow\python\keras\layers\core.py:143: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %% [markdown]
# ### Train CNN

# %%
from keras.utils import plot_model

# print(model.summary())
if not os.path.exists(savedir):
    os.makedirs(savedir)

plot_model(model, to_file=(savedir + 'model.png'))
# Out:
# Using TensorFlow backend.

# %%
# train_data = train_data.reshape(train_data.shape[0], train_data.shape[1], train_data.shape[2], 1)
# test_data = test_data.reshape(test_data.shape[0], test_data.shape[1], test_data.shape[2], 1)

# The patience parameter is the amount of epochs to check for improvement
early_stop = keras.callbacks.EarlyStopping(monitor='val_mean_absolute_error', patience=25)

history = model.fit(train_data, train_labels, validation_data=(test_data, test_labels), epochs=75, batch_size=32, verbose=1, callbacks=[early_stop])
test_predic = model.predict(test_data)
train_predic = model.predict(train_data)

model.save(savedir + 'model.h5')

# sess.graph contains the graph definition; that enables the Graph Visualizer.

# file_writer = tf.summary.FileWriter(savedir + '/logs/', sess.graph)
# Out:
# Train on 23352 samples, validate on 6672 samples
# WARNING:tensorflow:From C:\Users\Nicholas\Anaconda3\envs\Aion\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/75
# 23352/23352 [==============================] - 219s 9ms/sample - loss: 0.2174 - mean_absolute_error: 1.5967 - acc: 0.0000e+00 - val_loss: 0.1326 - val_mean_absolute_error: 1.1439 - val_acc: 0.0000e+00
# Epoch 2/75
# 23352/23352 [==============================] - 199s 9ms/sample - loss: 0.1559 - mean_absolute_error: 1.3172 - acc: 0.0000e+00 - val_loss: 0.1012 - val_mean_absolute_error: 0.9868 - val_acc: 0.0000e+00
# Epoch 3/75
# 23352/23352 [==============================] - 205s 9ms/sample - loss: 0.1404 - mean_absolute_error: 1.2436 - acc: 0.0000e+00 - val_loss: 0.0863 - val_mean_absolute_error: 0.9608 - val_acc: 0.0000e+00
# Epoch 4/75
# 23352/23352 [==============================] - 195s 8ms/sample - loss: 0.1269 - mean_absolute_error: 1.1720 - acc: 0.0000e+00 - val_loss: 0.0849 - val_mean_absolute_error: 0.9702 - val_acc: 0.0000e+00
# Epoch 5/75
# 23352/23352 [==============================] - 194s 8ms/sample - loss: 0.1217 - mean_absolute_error: 1.1401 - acc: 0.0000e+00 - val_loss: 0.0843 - val_mean_absolute_error: 0.9118 - val_acc: 0.0000e+00
# Epoch 6/75
# 23352/23352 [==============================] - 202s 9ms/sample - loss: 0.1121 - mean_absolute_error: 1.0965 - acc: 0.0000e+00 - val_loss: 0.0978 - val_mean_absolute_error: 1.0739 - val_acc: 0.0000e+00
# Epoch 7/75
# 23352/23352 [==============================] - 197s 8ms/sample - loss: 0.1055 - mean_absolute_error: 1.0620 - acc: 0.0000e+00 - val_loss: 0.0845 - val_mean_absolute_error: 0.9826 - val_acc: 0.0000e+00
# Epoch 8/75
# 23352/23352 [==============================] - 211s 9ms/sample - loss: 0.0992 - mean_absolute_error: 1.0267 - acc: 0.0000e+00 - val_loss: 0.0861 - val_mean_absolute_error: 0.9746 - val_acc: 0.0000e+00
# Epoch 9/75
# 23352/23352 [==============================] - 204s 9ms/sample - loss: 0.0925 - mean_absolute_error: 0.9944 - acc: 0.0000e+00 - val_loss: 0.0838 - val_mean_absolute_error: 0.9479 - val_acc: 0.0000e+00
# Epoch 10/75
# 23352/23352 [==============================] - 196s 8ms/sample - loss: 0.0906 - mean_absolute_error: 0.9865 - acc: 0.0000e+00 - val_loss: 0.1217 - val_mean_absolute_error: 1.2662 - val_acc: 0.0000e+00
# Epoch 11/75
# 23352/23352 [==============================] - 202s 9ms/sample - loss: 0.0850 - mean_absolute_error: 0.9606 - acc: 0.0000e+00 - val_loss: 0.1012 - val_mean_absolute_error: 1.1165 - val_acc: 0.0000e+00
# Epoch 12/75
# 23352/23352 [==============================] - 212s 9ms/sample - loss: 0.0822 - mean_absolute_error: 0.9381 - acc: 0.0000e+00 - val_loss: 0.0952 - val_mean_absolute_error: 1.0607 - val_acc: 0.0000e+00
# Epoch 41/75
# 23352/23352 [==============================] - 187s 8ms/sample - loss: 0.0515 - mean_absolute_error: 0.7771 - acc: 0.0000e+00 - val_loss: 0.0828 - val_mean_absolute_error: 0.9345 - val_acc: 0.0000e+00
# Epoch 42/75
# 23352/23352 [==============================] - 201s 9ms/sample - loss: 0.0509 - mean_absolute_error: 0.7728 - acc: 0.0000e+00 - val_loss: 0.0836 - val_mean_absolute_error: 0.9447 - val_acc: 0.0000e+00
# Epoch 43/75
# 23352/23352 [==============================] - 199s 9ms/sample - loss: 0.0509 - mean_absolute_error: 0.7689 - acc: 0.0000e+00 - val_loss: 0.0831 - val_mean_absolute_error: 0.9226 - val_acc: 0.0000e+00
# Epoch 44/75
# 23352/23352 [==============================] - 203s 9ms/sample - loss: 0.0509 - mean_absolute_error: 0.7702 - acc: 0.0000e+00 - val_loss: 0.0840 - val_mean_absolute_error: 0.9661 - val_acc: 0.0000e+00
# Epoch 45/75
# 23352/23352 [==============================] - 208s 9ms/sample - loss: 0.0497 - mean_absolute_error: 0.7625 - acc: 0.0000e+00 - val_loss: 0.0912 - val_mean_absolute_error: 1.0101 - val_acc: 0.0000e+00

# %% [markdown]
# ### Examine Results

# %%
import pandas as pd
def plot_history(history):
    hist = pd.DataFrame(history.history)
    hist['epoch'] = history.epoch

    plt.figure()
    plt.xlabel('Epoch')
    plt.ylabel('Mean Abs Error')
    plt.plot(hist['epoch'], hist['mean_absolute_error'],
           label='Train Error')
    plt.plot(hist['epoch'], hist['val_mean_absolute_error'],
           label = 'Validation Error')
#     plt.ylim([0,5])
    plt.legend()
    plt.savefig(savedir + "History.png", dpi = 600, bbox_inches='tight')
    plt.show()


plot_history(history)

# %%
# Score and visualize predictions
from scipy.stats import pearsonr

train_times = train_labels.flatten()
train_pred_times = train_predic.flatten()

# train_shear = train_labels[:,1]
# train_pred_shear = train_predic[:,1]

test_times = test_labels.flatten()
test_pred_times = test_predic.flatten()

# test_shear = test_labels[:,1]
# test_pred_shear = test_predic[:,1]

plt.figure()
# plt.scatter(train_times, train_pred_times, marker = '.', color = 'b', alpha = .1)
plt.scatter(test_times,test_pred_times, marker = ".", color = 'k', alpha = .1)
plt.plot([0, 9], [0, 9], '-r') 
plt.title('Test Data, R = '+str(np.round(pearsonr(test_times, test_pred_times)[0], 3)))
plt.xlim(0,9)
plt.ylim(0,9)
plt.xlabel('Actual Age [ln(sec)]')
plt.ylabel('Predicted Age [ln(sec)]')
plt.savefig(savedir + "Age_test.png", dpi = 600, bbox_inches='tight')
plt.show()

plt.figure()
plt.scatter(train_times, train_pred_times, marker = '.', color = 'b', alpha = .1)
plt.plot([0, 9], [0, 9], '-r') 
plt.title('Train Data, R = '+str(np.round(pearsonr(train_times, train_pred_times)[0], 3)))
plt.xlim(0,9)
plt.ylim(0,9)
plt.xlabel('Actual Age [ln(sec)]')
plt.ylabel('Predicted Age [ln(sec)]')
plt.savefig(savedir + "Age_train.png", dpi = 600, bbox_inches='tight')
plt.show()

# plt.figure()
# plt.scatter(test_shear,test_pred_shear, marker = ".", color = 'k', alpha = .1)
# plt.scatter(train_shear, train_pred_shear, marker = '.', color = 'b', alpha = .1)
# plt.title('R = '+str(np.round(pearsonr(test_shear, test_pred_shear)[0], 3)))
# plt.plot([0, 100], [0, 100], '-r')
# plt.xlim(0,50)
# plt.ylim(0,50)
# plt.xlabel('Actual Shear [N]')
# plt.ylabel('Predicted Shear [N]')
# plt.savefig(savedir + "Shear.png", dpi = 600, bbox_inches='tight')
# plt.show()
